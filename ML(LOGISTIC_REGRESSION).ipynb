# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6420ecac-dba6-41f0-806b-b22774700766" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6420ecac-dba6-41f0-806b-b22774700766">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
data=pd.read_csv(io.BytesIO(uploaded['heart_failure_clinical_records_dataset.csv']))

# %%
data.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
len(data)
# Out:
# 299

# %%
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=299, step=1)

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
data.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
# ...

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
sns.countplot(x='DEATH_EVENT',data=data)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
sns.countplot(x='DEATH_EVENT',data=data,hue='sex')
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
data.isna()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
# ...

# %%
data.isna().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
pd.get_dummies(data['sex'])
# Out:
#      0  1
# 0    0  1
# 1    0  1
# 2    0  1
# 3    0  1
# 4    1  0
# ..  .. ..
# 294  0  1
# 295  1  0
# 296  1  0
# 297  0  1
# 298  0  1
#
# [299 rows x 2 columns]

# %%
pd.get_dummies(data['sex'],drop_first=True)
# Out:
#      1
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# ..  ..
# 294  1
# 295  0
# 296  0
# 297  1
# 298  1
#
# [299 rows x 1 columns]

# %%
gender=pd.get_dummies(data['sex'],drop_first=True)

# %%
data['Gender']=gender

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT', 'Gender'],
#       dtype='object')

# %%
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT  Gender
# 0        0     4            1       1
# ...

# %%
data.drop(['sex','anaemia','time','serum_sodium'],axis=1,inplace=True)

# %%
data.head()
# Out:
#     age  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0                       582         0                 20
# 1  55.0                      7861         0                 38
# 2  65.0                       146         0                 20
# 3  50.0                       111         0                 20
# 4  65.0                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  smoking  DEATH_EVENT  \
# 0                    1  265000.00               1.9        0            1
# 1                    0  263358.03               1.1        0            1
# 2                    0  162000.00               1.3        1            1
# 3                    0  210000.00               1.9        0            1
# 4                    0  327000.00               2.7        0            1
#
#    Gender
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0

# %%
x=data[['age', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'smoking']]
y=data[['DEATH_EVENT']]

# %%
x
# Out:
#       age  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0                       582         0                 20
# 1    55.0                      7861         0                 38
# 2    65.0                       146         0                 20
# 3    50.0                       111         0                 20
# 4    65.0                       160         1                 20
# ..    ...                       ...       ...                ...
# 294  62.0                        61         1                 38
# 295  55.0                      1820         0                 38
# 296  45.0                      2060         1                 60
# 297  45.0                      2413         0                 38
# 298  50.0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  smoking
# 0                      1  265000.00               1.9        0
# ...

# %%
y
# Out:
#      DEATH_EVENT
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 294            0
# 295            0
# 296            0
# 297            0
# 298            0
#
# [299 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
predict=lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[57,  0],
#        [42,  0]])

# %%
pd.DataFrame(confusion_matrix(y_test,predict),columns=['Predictred NO','predictred YES'],index=['Actual NO','Actual YES'])
# Out:
#             Predictred NO  predictred YES
# Actual NO              57               0
# Actual YES             42               0

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73        57
#            1       0.00      0.00      0.00        42
#
#     accuracy                           0.58        99
#    macro avg       0.29      0.50      0.37        99
# weighted avg       0.33      0.58      0.42        99
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
filename = 'condition_pred'
pickle.dump(lr,open(filename,'wb'))

# %%
filename = 'condition_pred'
loaded_model = pickle.load(open(filename,'rb'))

# %%
pred_result = loaded_model.predict([[39,3,219,0,0,140,0,2]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(pred_result)
# Out:
# [0]
